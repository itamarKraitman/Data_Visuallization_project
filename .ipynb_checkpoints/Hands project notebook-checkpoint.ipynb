# %%
import pandas as pd
import glob
import numpy as np

# %%
#uploading the data, using glob function
paricipants = glob.glob(r'C:\Users\meirk\Desktop\final_project_files\extraFiles\Training' + "/*")
participants_list = []
for i, participant in enumerate(paricipants):
    participants_files = glob.glob(participant + "/*.csv")
    labels = ["Spontan","sync","Alone"]
    
    for file in participants_files:
        df = pd.read_csv(file, index_col=None, header=0)
        for j, label in enumerate(labels):
            if label in file:
                df["label"] = j
                df["name"] = i
                #removing first 7 seconds from df
                df = (df[df["Time"] > (df["Time"][0] + 7)])
        participants_list.append(df)

DataFrame = pd.concat(participants_list, axis=0, ignore_index=True)

# %%
DataFrame
# Out:
#              Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0        71.41422      98073       left         2   -109.80610     228.3820
# 1        71.41422      98073      right         2    136.72260     201.6860
# 2        71.43108      98075       left         2   -110.42900     230.8011
# 3        71.43108      98075      right         2    137.02470     205.0279
# 4        71.44753      98076       left         2   -110.42230     231.4766
# ...           ...        ...        ...       ...          ...          ...
# 313080  856.26310      67309      right         2    101.91230     212.0264
# 313081  856.29580      67311       left         2    -81.57359     183.5054
# 313082  856.29580      67311      right         2    103.84750     214.7484
# 313083  856.32950      67314       left         2    -84.05124     187.8450
# 313084  856.32950      67314      right         2    106.11880     218.0190
#
# ...

# %%
DataFrame.loc[(DataFrame[' Hand Type']) == 'left'," Hand Type"] = int(0)
DataFrame.loc[(DataFrame[' Hand Type']) == 'right'," Hand Type"] = int(1)
DataFrame[" Hand Type"] = DataFrame[' Hand Type'].astype(int)

# %%
DataFrame
# Out:
#              Time   Frame ID   Hand Type   # hands   Position X   Position Y  \
# 0        71.41422      98073           0         2   -109.80610     228.3820
# 1        71.41422      98073           1         2    136.72260     201.6860
# 2        71.43108      98075           0         2   -110.42900     230.8011
# 3        71.43108      98075           1         2    137.02470     205.0279
# 4        71.44753      98076           0         2   -110.42230     231.4766
# ...           ...        ...         ...       ...          ...          ...
# 313080  856.26310      67309           1         2    101.91230     212.0264
# 313081  856.29580      67311           0         2    -81.57359     183.5054
# 313082  856.29580      67311           1         2    103.84750     214.7484
# 313083  856.32950      67314           0         2    -84.05124     187.8450
# 313084  856.32950      67314           1         2    106.11880     218.0190
#
# ...
